# %% [markdown]
# # SQL Magic Test

# %%
# %load_ext sql_magic

# %%
from sqlalchemy import create_engine
from sqlite3 import dbapi2 as sqlite
from BokehHelper import BokehPlotter


url = 'postgresql://postgres:test#123@localhost:5432/bdba'
db_con = create_engine(url, client_encoding='utf8')
plotter = BokehPlotter()

# %%
# %config SQL.conn_name='db_con'

# %%
# %%read_sql result
# select longitude, latitude from service_request where borough = 'BROOKLYN'
# Out:
# Query started at 08:13:13 PM Mitteleuropäische Zeit; Query executed in 0.00 m
#     longitude   latitude
# 0  -73.934148  40.585122
# 1  -73.946010  40.688985
# 2  -73.906046  40.689124
# 3  -73.924753  40.682435
# 4  -74.016910  40.639915
# 5  -73.997798  40.644854
# 6  -73.924245  40.704621
# 7  -74.004223  40.639614
# 8  -73.976369  40.654304
# 9  -73.924245  40.704621
# 10 -73.952943  40.664574
# 11 -73.943908  40.679320
# 12 -74.035718  40.639403
# 13 -74.035718  40.639403
# 14 -73.929860  40.667740
# 15 -73.920168  40.687474
# 16 -73.965666  40.652389
# 17 -73.909356  40.691402
# 18 -74.017239  40.603988
# 19 -73.882743  40.665366
# 20 -74.035621  40.638705
# 21 -74.030332  40.639591
# 22 -73.930168  40.614258
# 23 -73.949402  40.598972

# %%
plotter.plot_bar(notebook=True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="578cf5bb-8f46-4f2a-8d18-21a4f52df528">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ae65c9ca-1835-4606-8fde-17096faf269c"></div>
# </div>
