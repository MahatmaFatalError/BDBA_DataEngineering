# %% [markdown]
# # SQL Magic Test

# %%
# %load_ext sql

# %%
from BokehHelper import BokehPlotter

# %%
# %sql postgresql://postgres:test#123@localhost:5432/bdba
plotter = BokehPlotter()

# %%
result = %sql select descriptor, count(*) from service_request group by descriptor
# Out:
# 29 rows affected.

# %%
x_values_raw = result.dict()['descriptor']
x_values = []
for entry in x_values_raw:
    x_values.append(entry.strip())

y_values = list(result.dict()['count'])

# %%
plotter.plot_bar(x_values=x_values, y_values=y_values, notebook=True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3d95c4b0-3bd1-473c-8823-58a74e7201e8">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="969c6ff9-fde0-472f-8ba1-b7975c0c97ac"></div>
# </div>

# %% [markdown]
# ### Datetime
